# %%
# import torch
import argparse
import joblib
from pathlib import Path
import os

from tqdm import tqdm

import numpy as np
import pandas as pd

from sklearn.model_selection import KFold
from sklearn.svm import SVR, LinearSVR
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.cross_decomposition import PLSRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.model_selection import GridSearchCV
import xgboost as XGB

import plotnine as p9

# %%
data_path = '/nobackup/users/hmbaghda/metastatic_potential/'

# %%
res = pd.read_csv(os.path.join(data_path, 'processed', 'coarse_model_tests.csv'), index_col = 0)
res.groupby('model_type').test_pearson.mean().sort_values(ascending = False)
# Out:
# model_type
# PLSR          0.376988
# elasticNet    0.370737
# svm           0.362755
# rf            0.302660
# Name: test_pearson, dtype: float64

# %%
res_hvg_out = pd.read_csv(os.path.join(data_path, 'processed', 'hvg_coarse_model_tests.csv'), index_col = 0)
res_hvg_out.groupby('model_type').test_pearson.mean().sort_values(ascending = False)
# Out:
# model_type
# PLSR          0.396928
# svm           0.371084
# elasticNet    0.366895
# rf            0.336032
# knn           0.235397
# xgboost       0.221204
# Name: test_pearson, dtype: float64

# %%
res_hvg_in = pd.read_csv(os.path.join(data_path, 'processed', 'hvg_internal_coarse_model_tests.csv'), index_col = 0)
res_hvg_in.groupby('model_type').test_pearson.mean().sort_values(ascending = False)
# Out:
# model_type
# elasticNet    0.376176
# svm           0.374258
# PLSR          0.323554
# rf            0.320223
# knn           0.259951
# xgboost       0.229400
# Name: test_pearson, dtype: float64

# %%
res_da = pd.read_csv(os.path.join(data_path, 'processed', 'da_coarse_model_tests.csv'), index_col = 0)
res_da.groupby('model_type').test_pearson.mean().sort_values(ascending = False)
# Out:
# model_type
# PLSR     0.390296
# ridge    0.366935
# Name: test_pearson, dtype: float64

# %%
ast.literal_eval(res.loc[idx, 'best_params'])
# Out:
# {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'kernel': 'linear'}

# %%
res.head(10)
# Out:
#   model_type  fold  train_pearson  test_pearson           best_params
# 0       PLSR     0       0.999541      0.206836  {'n_components': 12}
# 1       PLSR     1       0.887889      0.208972   {'n_components': 4}
# 2       PLSR     2       0.895865      0.464922   {'n_components': 4}
# 3       PLSR     3       0.900876      0.434596   {'n_components': 4}
# 4       PLSR     4       0.892195      0.532019   {'n_components': 4}
# 5       PLSR     5       0.908728      0.275733   {'n_components': 4}
# 6       PLSR     6       0.999904      0.435449  {'n_components': 14}
# 7       PLSR     7       0.907147      0.359425   {'n_components': 4}
# 8       PLSR     8       0.888426      0.499843   {'n_components': 4}
# 9       PLSR     9       0.892109      0.352088   {'n_components': 4}

# %%
res
# Out:
#     model_type  fold  train_pearson  test_pearson  \
# 0         PLSR     0       0.999541      0.206836
# 1         PLSR     1       0.887889      0.208972
# 2         PLSR     2       0.895865      0.464922
# 3         PLSR     3       0.900876      0.434596
# 4         PLSR     4       0.892195      0.532019
# 5         PLSR     5       0.908728      0.275733
# 6         PLSR     6       0.999904      0.435449
# 7         PLSR     7       0.907147      0.359425
# 8         PLSR     8       0.888426      0.499843
# 9         PLSR     9       0.892109      0.352088
# 10  elasticNet     0       0.983184      0.225714
# 11  elasticNet     1       0.832389      0.070204
# 12  elasticNet     2       0.981898      0.573404
# 13  elasticNet     3       0.836567      0.364521
# 14  elasticNet     4       0.983906      0.555814
# 15  elasticNet     5       0.983529      0.163856
# 16  elasticNet     6       0.982542      0.461178
# 17  elasticNet     7       0.833612      0.350557
# 18  elasticNet     8       0.837561      0.493388
# 19  elasticNet     9       0.983053      0.448731
# 20         svm     0       0.999081      0.216106
# 21         svm     1       0.999085      0.304452
# 22         svm     2       0.999038      0.573318
# 23         svm     3       0.999348      0.180911
# 24         svm     4       0.998958      0.495965
# 25         svm     5       0.998898      0.124528
# 26         svm     6       0.998990      0.432902
# 27         svm     7       0.999013      0.336963
# 28         svm     8       0.998940      0.514311
# 29         svm     9       0.999120      0.448100
# 30          rf     0       0.991527      0.188821
# 31          rf     1       0.990128     -0.070538
# 32          rf     2       0.991388      0.683481
# 33          rf     3       0.992196      0.156240
#
#                                           best_params
# 0                                {'n_components': 12}
# 1                                 {'n_components': 4}
# 2                                 {'n_components': 4}
# 3                                 {'n_components': 4}
# 4                                 {'n_components': 4}
# 5                                 {'n_components': 4}
# 6                                {'n_components': 14}
# 7                                 {'n_components': 4}
# 8                                 {'n_components': 4}
# 9                                 {'n_components': 4}
# 10         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 11        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 12         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 13        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 14         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 15         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 16         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 17        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 18        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 19         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 20  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 21  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 22  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 23  {'C': 0.01, 'degree': 3, 'gamma': 0.001, 'kern...
# 24  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 25  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 26  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 27  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 28  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 29  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 30                              {'n_estimators': 350}
# 31                              {'n_estimators': 850}
# 32                              {'n_estimators': 350}
# 33                              {'n_estimators': 600}

# %%
for idx in res[res.model_type == 'svm'].index.tolist():
    print(ast.literal_eval(res.loc[idx, 'best_params'])['epsilon'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[388], line 2
#       1 for idx in res[res.model_type == 'svm'].index.tolist():
# ----> 2     print(ast.literal_eval(res.loc[idx, 'best_params'])['epsilon'])
#
# KeyError: 'epsilon'

# %%
res
# Out:
#     model_type  fold  train_pearson  test_pearson  \
# 0         PLSR     0       0.999541      0.206836
# 1         PLSR     1       0.887889      0.208972
# 2         PLSR     2       0.895865      0.464922
# 3         PLSR     3       0.900876      0.434596
# 4         PLSR     4       0.892195      0.532019
# 5         PLSR     5       0.908728      0.275733
# 6         PLSR     6       0.999904      0.435449
# 7         PLSR     7       0.907147      0.359425
# 8         PLSR     8       0.888426      0.499843
# 9         PLSR     9       0.892109      0.352088
# 10  elasticNet     0       0.983184      0.225714
# 11  elasticNet     1       0.832389      0.070204
# 12  elasticNet     2       0.981898      0.573404
# 13  elasticNet     3       0.836567      0.364521
# 14  elasticNet     4       0.983906      0.555814
# 15  elasticNet     5       0.983529      0.163856
# 16  elasticNet     6       0.982542      0.461178
# 17  elasticNet     7       0.833612      0.350557
# 18  elasticNet     8       0.837561      0.493388
# 19  elasticNet     9       0.983053      0.448731
# 20         svm     0       0.999081      0.216106
# 21         svm     1       0.999085      0.304452
# 22         svm     2       0.999038      0.573318
# 23         svm     3       0.999348      0.180911
# 24         svm     4       0.998958      0.495965
# 25         svm     5       0.998898      0.124528
# 26         svm     6       0.998990      0.432902
# 27         svm     7       0.999013      0.336963
# 28         svm     8       0.998940      0.514311
# 29         svm     9       0.999120      0.448100
# 30          rf     0       0.991527      0.188821
# 31          rf     1       0.990128     -0.070538
# 32          rf     2       0.991388      0.683481
# 33          rf     3       0.992196      0.156240
#
#                                           best_params
# 0                                {'n_components': 12}
# 1                                 {'n_components': 4}
# 2                                 {'n_components': 4}
# 3                                 {'n_components': 4}
# 4                                 {'n_components': 4}
# 5                                 {'n_components': 4}
# 6                                {'n_components': 14}
# 7                                 {'n_components': 4}
# 8                                 {'n_components': 4}
# 9                                 {'n_components': 4}
# 10         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 11        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 12         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 13        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 14         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 15         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 16         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 17        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 18        {'alpha': 100, 'l1_ratio': np.float64(0.0)}
# 19         {'alpha': 10, 'l1_ratio': np.float64(0.0)}
# 20  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 21  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 22  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 23  {'C': 0.01, 'degree': 3, 'gamma': 0.001, 'kern...
# 24  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 25  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 26  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 27  {'C': 0.01, 'degree': 2, 'gamma': 0.001, 'kern...
# 28  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 29  {'C': 0.001, 'degree': 2, 'gamma': 0.001, 'ker...
# 30                              {'n_estimators': 350}
# 31                              {'n_estimators': 850}
# 32                              {'n_estimators': 350}
# 33                              {'n_estimators': 600}
